# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; background-color: #dff0d8; border-color: #d6e9c6; font-weight: bold;">
#     <br><br>
#     <div style="font-weight: bold; font-size: 40px">파이썬으로 끝내는 데이터 과학</div>
#     <div style="font-weight: bold; font-size: 20px">[18] matplot을 이용한 데이터 시각화-3</div>
#     <hr style="width:80%;text-align:left;margin-left:0;border:0.5px solid green">
#     <br>
#     &#x2022; 막대그래프로 나타낼 데이터를 고를 수 있다.<br>
#     &#x2022; 막대그래프를 그릴 수 있다.<br>
#     &#x2022; 원그래프로 나타낼 데이터를 고를 수 있다.<br>
#     &#x2022; 원그래프를 그릴 수 있다.<br>
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     <font color=black>
#     🙋 <b>Pandas, Pyplot</b>을 사용하기 위해서 다음 선언문을 실행하세요.
#     </font>
# </div>

# %%
import pandas as pd  # 판다스를 pd로 축약하여 불러옵니다.
import matplotlib.pyplot as plt  # Pyplot을 plt로 축약하여 불러옵니다.

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>1. 막대그래프로 데이터 시각화</h2>
# </div>

# %% [markdown]
# ###  **1. 막대그래프와 데이터**

# %% [markdown]
# **(1) 막대그래프를 위한 데이터**
#
# > 다음은 2023년 1월 동안의 인구 변화량을 막대그래프로 나타낸 것입니다.
# > 전체 인구에 대한 막대그래프를 통해 전체 인구가 증가했는지 감소했는지 쉽게 판단할 수 있습니다.
# > 또한 남성, 여성에 대해 나뉘어진 막대그래프를 통해 남녀별 인구 변화량을 쉽게 비교할 수 있습니다.
# >
# > ![image.png](attachment:bb4db6a8-55b6-41cf-87b4-4ddd636dbe6e.png)
# > 출처: 행정안전부 주민등록 인구통계

# %% [markdown]
# > **각 범주(category)별로 분포한 대상의 빈도수를 비교할 데이터를 더 알아봅시다.**
# > * 대통령 후보별 득표 수
# > * 행정구역별 공공 와이파이 수
# > * 학생별 시험 점수
# > * 주식별 주가 변동률
# >
# > **위에 소개한 예시 이외에 막대그래프로 표현하면 좋을 데이터를 아랫칸에 적어봅시다.**

# %% [raw]
#       👉 (...) 별 (...)

# %% [markdown]
# ### **2. 막대그래프 그리기**
#
# > matplotlib.pyplot 은 하나의 그래프를 figure라는 단위로 나타냅니다.
# > 그래프를 얻기 위해서는 빈 figure에 원하는 그래프를 그린 후 출력하는 두가지 단계를 밟아야합니다.
# > 막대그래프는 `bar` 함수로 그릴 수 있습니다.
# >
# > ①  `plt.bar(data)` 를 통해 빈 figure에 데이터를 이용한 막대그래프를 그릴 수 있습니다.
# > ②  `plt.show()` 를 통해 figure를 출력할 수 있습니다.

# %% [markdown]
# **(1) 리스트 이용하기**
#
# > List 형태의 데이터를 다음과 같이 `bar` 함수로 막대그래프로 나타낼 수 있습니다.
# >
# > `plt.bar(List_X, List_Y)`
# > : List_X (숫자나 문자를 담은 리스트) 에 따른 List_Y (숫자를 담은 리스트) 데이터를 막대그래프로 그림
# >
# > 그래프를 출력하기 위해서는 반드시 다음 코드를 연이어 실행해야합니다.
# > `plt.show()`

# %%
# 예제 1: List 데이터로 막대그래프 그리기

기호 = ['1번', '2번', '3번', '4번', '5번', '6번', '7번']
득표수 = [50, 120, 36, 21, 50, 19, 95]

plt.bar(기호, 득표수)  # 빈 figure에 막대그래프를 그림
plt.title("학생회장 선거 득표수")
plt.show()  # figure를 출력

# %% [markdown]
# > 각 데이터를 색깔로 구분하고 싶다면 다음과 같이 막대의 색을 변경할 수 있습니다.
# >
# > `plt.bar(List_X, List_Y, color=List_color)`
# >: 각 막대의 색정보를 담은 리스트(List_color)를 color 인수에 지정해줍니다.
# >
# > 색깔별로 이름이 정해져 있습니다.
# > * 검정/하얀색: k/w
# > * 빨강/초록/파랑: r/g/b
# > * 회색/주황/노랑/남색/보라/핑크: gray/orange/yellow/navy/purple/pink
# > * 더 다양한 색깔 정보 [링크!](https://matplotlib.org/stable/gallery/color/named_colors.html#sphx-glr-gallery-color-named-colors-py)
# >

# %%
# 예제 2: List 데이터로 막대그래프 그리고 막대 색깔 지정하기

C = ['gray', 'orange', 'yellow', 'g', 'navy', 'purple', 'pink']

plt.bar(기호, 득표수, color=C)  # 빈 figure에 막대그래프를 그림
plt.title("학생회장 선거 득표수")
plt.show()  # figure를 출력

# %% [markdown]
# #### <연습문제>
#
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="x2tF_sUzQK4" href='#jce-judge/open/x2tF_sUzQK4' target='_self'><span>막대그래프 그리기 - 프로듀스101</span></a>
#
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="T_qDlw2iDIw" href='#jce-judge/open/T_qDlw2iDIw' target='_self'><span>막대그래프 그리기 - 소풍장소 투표 결과</span></a>

# %% [markdown]
# **(2) 판다스 Series 이용하기**
#
# > Pandas.Series 형태의 데이터를 다음과 같이 `bar` 함수로 막대그래프로 나타낼 수 있습니다.
# >
# > `plt.bar(Series1, Series2)`
# > : Series1 에 따른 Series2 데이터를 막대그래프로 그림
# >
# > 그래프를 출력하기 위해서는 반드시 다음 코드를 연이어 실행해야합니다.
# > `plt.show()`

# %% [markdown]
# > **202301인구현황.csv** 파일에는 2023년 1월 기준 대한민국의 범주별 인구 수가 저장되어 있습니다.
# > 지열별로 청소년 인구 수를 비교하기 위해 *청소년 인구현황*을 그래프로 나타내어 봅시다.

# %%
# 예제 3: csv 파일을 읽어서 데이터 가져오기

인구현황 = pd.read_csv("https://tmn-bucket-materials-all.s3.ap-northeast-2.amazonaws.com/data/202301%EC%9D%B8%EA%B5%AC%ED%98%84%ED%99%A9.csv", index_col=0)
인구현황
# Out:
#             전체       남자       여자       아동     아동남자     아동여자      청소년    청소년남자  \
# 행정구역
# 서울     9424873  4567739  4857134  1125845   578262   547583  1390027   688495
# 부산     3316107  1618749  1697358   416189   213644   202545   473431   243220
# 대구     2362880  1162217  1200663   327943   168620   159323   377513   196984
# 인천     2969502  1486300  1483202   426032   218528   207504   465197   239758
# 광주     1429816   706724   723092   225019   115843   109176   260106   134773
# 대전     1445806   721037   724769   211859   109201   102658   247413   127462
# 울산     1110074   570113   539961   173435    89651    83784   180403    96569
# 세종      384496   191769   192727    87283    44226    43057    72460    36901
# 경기    13596091  6842226  6753865  2099644  1074587  1025057  2244687  1156923
# 강원     1535373   772297   763076   199498   102737    96761   227189   121001
# 충북     1594459   810740   783719   224841   115544   109297   246328   129842
# ...

# %%
# 예제 4: Pandas.Series 데이터로 막대그래프 그리기

plt.bar(인구현황.index, 인구현황.청소년)  # 빈 figure에 막대그래프를 그림
plt.title("2023년 1월 청소년 인구현황")  # figure의 제목을 작성 
plt.show()  # figure를 출력

# %% [markdown]
# > 막대그래프는 각 범주별 수치를 비교하는게 목적이므로 y축 눈금을 나타내는 격자(안내선)를 추가하면 유용합니다.
# > 다음과 같이 각 축의 격자를 추가할 수 있습니다.
# >
# > `plt.grid(axis='x')` : figure의 x축 격자를 그림
# > `plt.grid(axis='y')` : figure의 y축 격자를 그림
# > `plt.grid()` : figure의 x, y축 격자를 모두 그림

# %%
# 예제 5: Pandas.Series 데이터로 막대그래프 그리고 격자 추가하기

plt.bar(인구현황.index, 인구현황.청소년)  # 빈 figure에 막대그래프를 그림
plt.title("2023년 1월 청소년 인구현황")  # figure의 제목을 작성 
plt.grid(axis='y')  # y축 격자 추가
plt.show()  # figure를 출력

# %% [markdown]
# #### <연습문제>
#
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="MWYwgGRE6K0" href='#jce-judge/open/MWYwgGRE6K0' target='_self'><span>막대그래프 그리기 - 전국 눈일수 </span></a>

# %% [markdown]
# ### **3. 막대그래프 겹쳐서 그리기**
#
# > 막대그래프 여러개를 겹쳐서 그리려면 `bar` 함수로 연달아 그래프를 그리면 됩니다.
# > 주의할 점은, x축 값을 숫자로 만들고 두 그래프가 겹치지 않도록 다음과 같이 x값을 구분해주어야 합니다.
# >
# > `X = [0, 1, 2, ..., 데이터길이-1]`: 데이터의 길이와 같은 x축 값을 생성
# > `plt.bar(X, data1, width)`
# > : data1 데이터를 간격 1, 너비 width인 막대그래프로 그림
# > `plt.bar(X+width, data2, width)`
# > : data2 데이터를 위의 막대그래프보다 오른쪽으로 width만큼 떨어진 곳에 막대그래프로 그림
# >> 주의! range(n)으로 리스트 X를 만드는 경우 width가 실수형이면 계산이 불가능하기 때문에
# >>NumPy를 이용해 np.arange(n)으로 만드는 것이 좋습니다.
# >
# > x축 눈금의 이름을 바꾸려면 다음과 같이 눈금 이름을 바꾸어야 합니다.
# > `plt.xticks(X, data_X)`: x축 눈금의 이름을 X에서 data_X로 바꾸어 작성
# >
# > 그래프를 출력하기 위해서는 반드시 다음 코드를 연이어 실행해야합니다.
# > `plt.show()`
# >

# %% [markdown]
# > **202301인구현황.csv** 파일의 데이터를 이용하여
# > 지열별로 청소년 인구 수를 남녀별로 나타내는 막대그래프를 함께 나타내어 봅시다.

# %%
# 예제 5: 막대그래프 겹쳐서 그리기

import numpy as np  # numpy 라이브러리를 사용하기 위해 np로 축약하여 불러옵니다.

X = np.arange(len(인구현황.index))  # X축 데이터로 활용할 [0, 1, 2, ...] array를 생성

plt.bar(X, 인구현황.청소년남자, 0.4)  # 빈 figure에 0.4 너비의 막대그래프를 그림
plt.bar(X+0.4, 인구현황.청소년여자, 0.4)  # 위의 figure에 0.4 너비의 막대그래프를 겹쳐서 그림
plt.xticks(X, 인구현황.index)  # 그래프의 X축 라벨을 지역 이름으로 바꾸어 작성

plt.title("2023년 1월 남녀별 청소년 인구현황")  # figure의 제목을 작성 
plt.grid(axis='y')  # figure의 y축 격자를 그림
plt.legend(['남자', '여자'])  # 각 그래프의 범례를 작성
plt.show()  # figure를 출력

# %% [markdown]
# #### <연습문제>
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="HNra_MYZCBA" href='#jce-judge/open/HNra_MYZCBA' target='_self'><span>막대그래프 중첩 - 전국 강수일수 눈일수</span></a>

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>2. 원그래프로 데이터 시각화</h2>
# </div>

# %% [markdown]
# ###  **1. 원그래프와 데이터**

# %% [markdown]
# **(1) 그래프를 위한 데이터**
#
# > 다음은 2016년 간염환자 분포를 원그래프로 나타낸 것입니다.
# > 간염의 종류별로 환자가 나이대 별로 어떻게 분포되어 있는지 쉽게 알 수 있습니다.
# > A형은 20 ~ 40대, B형은 30 ~ 60대, C형은 40 ~ 70대가 대부분 점유하고 있음을 알 수 있습니다.
# > 이러한 정보를 분석하면 질병 관리 기획에 이용할 수 있을 것입니다.
# >
# > ![image.png](attachment:feed20c8-9721-402e-82c0-5f287bd8eaf6.png)
# > 출처: 건강보험심사평가원 생활 속 질병통계 100선

# %% [markdown]
# > **각 범주(category)별로 분포된 대상의 비율을 비교할 데이터를 더 알아봅시다.**
# > * 하루 일정 당 걸린 시간
# > * 음식의 탄수화물, 단백질, 지방 당 열량
# > * 컴퓨터 프로그램 언어 당 이용자 수
# > * 나이대별 인구 분포
# >
# > **위에 소개한 예시 이외에 원그래프로 표현하면 좋을 데이터를 아랫칸에 적어봅시다.**

# %% [raw]
#       👉 (...) 당/별 (...)

# %% [markdown]
# ### **2. 원그래프 그리기**
#
# > matplotlib.pyplot 은 하나의 그래프를 figure라는 단위로 나타냅니다.
# > 그래프를 얻기 위해서는 빈 figure에 원하는 그래프를 그린 후 출력하는 두가지 단계를 밟아야합니다.
# > 원그래프는 `pie` 함수로 그릴 수 있습니다.
# >
# > ①  `plt.pie(data)` 를 통해 빈 figure에 데이터를 이용한 원그래프를 그릴 수 있습니다.
# > ②  `plt.show()` 를 통해 figure를 출력할 수 있습니다.

# %% [markdown]
# **(1) 리스트 이용하기**
#
# > List 형태의 데이터를 다음과 같이 `pie` 함수로 막대그래프로 나타낼 수 있습니다.
# >
# > `plt.pie(List_Y, labels=List_X)`
# > : List_X (숫자나 문자를 담은 리스트) 에 따른 List_Y (숫자를 담은 리스트) 데이터를 원그래프로 그림
# >
# > 그래프를 출력하기 위해서는 반드시 다음 코드를 연이어 실행해야합니다.
# > `plt.show()`

# %%
# 예제 1: List 데이터로 원그래프 그리기

기호 = ['1번', '2번', '3번', '4번', '5번', '6번', '7번']
득표수 = [50, 120, 36, 21, 50, 19, 95]

plt.pie(득표수, labels=기호)  # 빈 figure에 득표수에 따라 다른 넓이를 가지도록 원그래프를 그림
plt.title("학생회장 선거 득표 비율")
plt.show()  # figure를 출력

# %% [markdown]
# > 원그래프에서는 각 부채꼴을 나타내는 데이터가 얼마의 비율을 차지하는지 적어주는 것이 좋습니다.
# >
# > `plt.pie(List_Y, labels=List_X, autopct='%f')`
# >: 각 부채꼴이 차지하는 비율을 작성
# >
# > 나타내고 싶은 자리수에 따라 다른 기호를 이용합니다.
# >* `%d` :  정수로 표현
# >* `%.1f` : 소수 첫째 자리까지 표현
# >* `%.2f` : 소수 둘째 자리까지 표현

# %% [markdown]
# > 원그래프가 그려질때는 기본적으로 시계반대방향으로 그려집니다.
# > 시계방향으로 바꾸고 싶다면 `counterclock=False` 로 인수를 지정해주면 됩니다.

# %%
# 예제 2: List 데이터로 원그래프 그리고 비율 쓰기

plt.pie(득표수, labels=기호, autopct='%.1f', counterclock=False)  
# 빈 figure에 득표수에 따라 다른 넓이를 가지도록 원그래프를 시계방향으로 그리고 비율을 소수 첫째 자리까지 작성
plt.title("학생회장 선거 득표 비율")
plt.show()  # figure를 출력

# %% [markdown]
# #### <연습문제>
#
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="yJNsKxhPy2k" href='#jce-judge/open/yJNsKxhPy2k' target='_self'><span>원그래프 그리기 - 하루일과</span></a>
#
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="nVy3A-rDz7k" href='#jce-judge/open/nVy3A-rDz7k' target='_self'><span>원그래프 그리기 - 닭가슴살 열량 분포</span></a>

# %% [markdown]
# **(2) 판다스 Series 이용하기**
#
# > Pandas.Series 형태의 데이터를 다음과 같이 `pie` 함수로 원그래프로 나타낼 수 있습니다.
# >
# > `plt.pie(Series2, labels=Series1)`
# > : Series1 에 따른 Series2 데이터를 원그래프로 그림
# >
# > 그래프를 출력하기 위해서는 반드시 다음 코드를 연이어 실행해야합니다.
# > `plt.show()`

# %% [markdown]
# > 다음은 2022년 동안 거래된 소프트웨어의 프로그램 언어 비율을 조사한 것입니다.
# >
# >1. Python – 29.48%
# 2. Java – 17.18%
# 3. JavaScript – 9.14%
# 4. C# – 6.94%
# 5. PHP – 6.49%
# 6. C/C++ – 6.49%
# 7. R – 3.59%
# 8. TypeScript – 2.18%
# 9. Swift – 2.1%
# 10. Objective-C – 2.06%
# >
# > 위 자료를 이용하여 2022년 컴퓨터 프로그램 언어 사용률을 원그래프로 나타내어 봅시다.

# %%
# 예제 3: Pandas Series 만들기

language = pd.Series(data=[29.48, 17.18, 9.14, 6.94, 6.49, 6.49, 3.59, 2.18, 2.1, 2.06],
                    index=['Python', 'Java', 'JavaScript', 'C#', 'PHP', 'C/C++', 'R', 'TypeScript', 'Swift', 'Objective-C'])

print(language)  # Series를 출력
print('\n합:', language.sum())  # Series 값의 합을 출력
# Out:
# Python         29.48
# Java           17.18
# JavaScript      9.14
# C#              6.94
# PHP             6.49
# C/C++           6.49
# R               3.59
# TypeScript      2.18
# Swift           2.10
# Objective-C     2.06
# dtype: float64
#
# 합: 85.64999999999999

# %% [markdown]
# > 상위 10개의 프로그램 언어의 사용률을 다 더하니 100% 가 되지 않습니다.
# > 따라서 나머지 언어들의 사용률을 구해서 `others`(나머지)라는 이름의 행을 추가해봅시다.

# %%
# 예제 4: Pandas Series 행 추가하기

language.loc['others'] = 100 - language.sum()

language
# Out:
# Python         29.48
# Java           17.18
# JavaScript      9.14
# C#              6.94
# PHP             6.49
# C/C++           6.49
# R               3.59
# TypeScript      2.18
# Swift           2.10
# Objective-C     2.06
# others         14.35
# dtype: float64

# %%
# 예제 5: Pandas.Series 데이터로 막대그래프 그리기

plt.pie(language, labels=language.index, autopct='%.1f')
# 빈 figure에 사용률에 따라 다른 넓이를 가지도록 원그래프를 그리고 비율을 소수 첫째 자리까지 작성
plt.title("2022년 프로그램 언어별 사용률")  # figure의 제목을 작성 
plt.show()  # figure를 출력

# %% [markdown]
# #### <연습문제>
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="Qj8yA_9g3vI" href='#jce-judge/open/Qj8yA_9g3vI' target='_self'><span>원그래프 그리기 - 우리나라 인구분포</span></a>

# %% [markdown]
# ### **3. 원그래프 꾸미기**

# %% [markdown]
# **(1) 부채꼴 색상 바꾸기**
#
# > 위에서 만든 원그래프를 보면 자동으로 지정되는 색상에 의해 나란히 있는 Python과 others 부채꼴의 색상이 겹칩니다.
# > 원하는 색의 이름을 담은 리스트로 부채꼴의 색을 변경할 수 있습니다.
# >
# > `plt.pie(data, labels=labels, color=List_color)`
# > : 각 부채꼴의 색정보를 담은 리스트(List_color)를 color 인수에 지정해줍니다.
# >
# >
# >* 검정/하얀색: k/w
# >* 빨강/초록/파랑: r/g/b
# >* 회색/주황/노랑/남색/보라/핑크: gray/orange/yellow/navy/purple/pink
# >* 더 다양한 색깔 정보 링크!

# %%
# 예제 6: Pandas.Series 데이터로 막대그래프 그리고 색상 변경하기

C = ['yellow', 'orange', 'g', 'b', 'navy', 'purple', 'pink', 'r', 'gray', 'k', 'w']

plt.pie(language, labels=language.index, autopct='%.1f', colors=C)  # 지정된 색깔의 부채꼴로 원그래프를 그림
plt.title("2022년 프로그램 언어별 사용률")  # figure의 제목을 작성 
plt.show()  # figure를 출력

# %% [markdown]
# **(2) 부채꼴 모양 바꾸기**
#
# > 각 부채꼴을 더 잘 구분하기 위해서 부채꼴에 모서리 선을 추가해도 좋습니다.
# > 또한 처음에 봤던 나이대별 간염환자의 분포 원그래프처럼 잘린 부채꼴 모양으로 나타낼 수도 있습니다.
# >
# > pie 함수의 `wedgeprops` 인수에 다음 정보를 담은 dictionary를 만들어 지정해주어야 합니다.
# >
# > * width: 반지름 대비 남겨지는 그래프의 너비 비율
# > * edgecolor: 부채꼴 모서리 선의 색깔
# > * linewidth: 부채꼴 모서리 선의 두께

# %%
# 예제 7: Pandas.Series 데이터로 막대그래프 그리고 부채꼴 모양 변경하기

wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 1}
# 원의 중심으로 부터 반지름의 30%에 해당하는 부분을 잘라냅니다. 
# 부채꼴에 두께가 1pixel이고 색상은 하얀 모서리 선을 그립니다.

C = ['yellow', 'orange', 'g', 'b', 'navy', 'purple', 'pink', 'r', 'gray', 'k', 'w']

plt.pie(language, labels=language.index, autopct='%.1f', colors=C, wedgeprops=wedgeprops)  
# 지정된 모양과 색깔의 부채꼴로 원그래프를 그림
plt.title("2022년 프로그램 언어별 사용률")  # figure의 제목을 작성 
plt.show()  # figure를 출력

# %% [markdown]
# #### <연습문제>
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="uf1PiXwR4Ts" href='#jce-judge/open/uf1PiXwR4Ts' target='_self'><span>원그래프 꾸미기 - 닭가슴살 열량 분포</span></a>

# %% [markdown]
# **(3) 부채꼴 움직이기**
#
# > 부채꼴의 중심을 움직일 수도 있습니다.
# >
# > 모두 같은 거리를 움직이면 부채꼴들을 구분하기가 좋습니다.
# > 하나의 부채꼴만 움직이면 강조할 수 있습니다.
# >
# > pie 함수의 `explode` 인수에 반지름의 몇 배 만큼 움직일 것인지 숫자를 넣은 리스트를 지정해주어야 합니다.
# >
# > `explode=[0.1, 0.1, 0.1]` : 세 개의 부채꼴 반지름의 0.1배만큼 이동
# > `explode=[0.1, 0, 0]` : 첫번째 부채꼴만 반지름의 0.1배만큼 이동

# %%
# 예제 8: Pandas.Series 데이터로 막대그래프 그리고 부채꼴 모두 이동하기

explodes = [0.02] * len(language)  # 데이터와 길이가 같고 모든 값이 0.02인 리스트

C = ['yellow', 'orange', 'g', 'b', 'navy', 'purple', 'pink', 'r', 'gray', 'k', 'w']

plt.pie(language, labels=language.index, autopct='%.1f', colors=C, explode=explodes)  
# 모든 부채꼴이 중심으로부터 반지름의 0.02배 만큼 떨어지도록 원그래프를 그림
plt.title("2022년 프로그램 언어별 사용률")  # figure의 제목을 작성 
plt.show()  # figure를 출력

# %%
# 예제 9: Pandas.Series 데이터로 막대그래프 그리고 하나의 부채꼴 이동하기

explodes = [0] * len(language)  # 데이터와 길이가 같고 모든 값이 0인 리스트
explodes[1] = 0.1  # 리스트의 두번째 값을 0.1로 변경

C = ['yellow', 'orange', 'g', 'b', 'navy', 'purple', 'pink', 'r', 'gray', 'k', 'w']

plt.pie(language, labels=language.index, autopct='%.1f', colors=C, explode=explodes)  
# 두번째 부채꼴이 중심으로부터 반지름의 0.1배 만큼 떨어지도록 원그래프를 그림
plt.title("2022년 프로그램 언어별 사용률")  # figure의 제목을 작성 
plt.show()  # figure를 출력

# %% [markdown]
# #### <연습문제>
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="nrY9TWfZX9g" href='#jce-judge/open/nrY9TWfZX9g' target='_self'><span>원그래프 꾸미기 - 우리나라 인구분포</span></a>
