# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; background-color: #dff0d8; border-color: #d6e9c6; font-weight: bold;">
#     <br><br>
#     <div style="font-weight: bold; font-size: 40px">파이썬으로 끝내는 데이터 과학</div>
#     <div style="font-weight: bold; font-size: 20px">[17] matplot을 이용한 데이터 시각화-2</div>
#     <hr style="width:80%;text-align:left;margin-left:0;border:0.5px solid green">
#     <br>
#     &#x2022; 산점도로 나타낼 데이터를 고를 수 있다.<br>
#     &#x2022; 산점도를 그릴 수 있다.<br>
#     &#x2022; 산점도로 겹쳐서 나타낼 데이터를 고를 수 있다.<br>
#     &#x2022; 산점도 여러개를 겹쳐 그릴 수 있다.<br>
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     <font color=black>
#     🙋 <b>Pandas, Pyplot</b>을 사용하기 위해서 다음 선언문을 실행하세요.
#     </font>
# </div>

# %%
import pandas as pd  # 판다스를 pd로 축약하여 불러옵니다.
import matplotlib.pyplot as plt  # Pyplot을 plt로 축약하여 불러옵니다.

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>1. 산점도로 데이터 시각화</h2>
# </div>

# %% [markdown]
# ###  **1. 산점도와 데이터**

# %% [markdown]
# **(1) 산점도를 위한 데이터**
#
# > 다음은 의사협회에서 조사한 나라별 국민 1인당 연간 의사방문 횟수와 진찰시간 데이터를 산점도로 나타낸 것입니다.
# > 그래프는 의사방문 횟수와 진찰시간 사이에 어느 관계가 있는지 보여줍니다.
# > 대략, 의사방문 횟수가 많을수록 진찰시간은 짧다는 것을 알 수 있습니다.
# >
# > ![image.png](attachment:ec465de5-a535-4749-acfd-383dda5910d2.png)
# > 출처: 대한의사협회 의료정책연구소

# %% [markdown]
# > **두 변수간의 관계를 나타내는 데이터를 더 알아봅시다.**
# > * 키 - 몸무게
# > * 모니터 사용 시간 - 시력
# > * 하루 운동 시간 - 체지방률
# > * 지역의 범죄율 - 집 가격
# >
# > **위에 소개한 예시 이외에 산점도로 표현하면 좋을 데이터를 아랫칸에 적어봅시다.**

# %% [raw]
#       👉 (...) - (...)

# %% [markdown]
# ### **2. 산점도 그리기**
#
#
# > matplotlib.pyplot 은 하나의 그래프를 figure라는 단위로 나타냅니다.
# > 그래프를 얻기 위해서는 빈 figure에 원하는 그래프를 그린 후 출력하는 두가지 단계를 밟아야합니다.
# > 산점도는 `scatter` 함수로 그릴 수 있습니다.
# >
# > ①  `plt.scatter(data)` 를 통해 빈 figure에 데이터를 이용한 산점도를 그릴 수 있습니다.
# > ②  `plt.show()` 를 통해 figure를 출력할 수 있습니다.

# %% [markdown]
# **(1) 리스트 이용하기**
#
# > List 형태의 데이터를 다음과 같이 `scatter` 함수로 산점도로 나타낼 수 있습니다.
# >
# > `plt.scatter(List_X, List_Y)`
# > : List_X (숫자를 담은 리스트) 에 따른 List_Y (숫자를 담은 리스트) 데이터를 산점도로 그림
# >
# > 그래프를 출력하기 위해서는 반드시 다음 코드를 연이어 실행해야합니다.
# > `plt.show()`

# %%
# 예제 1: List 데이터로 산점도 그리기

X1 = [-3, -2, -1, 1, 2, 4, 5, 6, 7, 8, 10]
Y1 = [-0.9, -0.6, -0.3, 0.3, 0.6, 1.2, 1.5, 1.8, 2.1, 2.4, 3.0]

plt.scatter(X1, Y1)  # 빈 figure에 산점도를 그림
plt.show()  # figure를 출력

# %% [markdown]
# > 그래프를 보면 X 값이 커질수록 Y 값이 함께 커지는 관계임을 알 수 있습니다.

# %% [markdown]
# #### <연습문제>
#
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="AhtEleJFFJ4" href='#jce-judge/open/AhtEleJFFJ4' target='_self'><span>산점도 - x값과 y값이 같은 점</span></a>

# %% [markdown]
# **(2) 넘파이 이용하기**
#
#
# > Numpy.array 형태의 데이터를 다음과 같이 `scatter` 함수로 산점도로 나타낼 수 있습니다.
# >
# > `plt.scatter(Array_X, Array_Y)`
# > : Array_X (숫자를 담은 array) 에 따른 Array_Y (숫자를 담은 array) 데이터를 산점도로 그림
# >
# > 그래프를 출력하기 위해서는 반드시 다음 코드를 연이어 실행해야합니다.
# > `plt.show()`

# %%
# 예제 2: Numpy.array 데이터로 산점도 그리기

import numpy as np  # numpy 라이브러리를 사용하기 위해 np로 축약하여 불러옵니다.

X2 = np.arange(0, 7, 0.1)  # 0 부터 0.1 간격으로 7 미만까지의 수를 array에 저장
Y2 = np.sin(X2) + (np.random.rand(len(X2)) - 0.5)  # X2 안의 수 x에 대해서 sin(x) 값에 난수(-0.5 ~ 0.5)를 더해 array에 저장

plt.scatter(X2, Y2)  # 빈 figure에 산점도를 그림
plt.show()  # figure를 출력

# %% [markdown]
# > 산점도는 두 데이터의 관계를 나타내므로 각 축이 어떤 데이터의 값인지 표현하는 것이 좋습니다.
# > 다음과 같이 각 축의 이름을 쓸 수 있습니다.
# >
# > `plt.xlabel("X축 label")` : figure의 x축에 이름을 작성
# > `plt.ylabel("Y축 label")` : figure의 y축에 이름을 작성

# %%
# 예제 3: Numpy.array 데이터로 산점도 그리고 축 이름 쓰기

plt.scatter(X2, Y2)  # 빈 figure에 산점도를 그림
plt.xlabel("X2")  # figure의 x축 이름 작성
plt.ylabel("Y2")  # figure의 y축 이름 작성
plt.show()  # figure를 출력

# %% [markdown]
# #### <연습문제>
#
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="Voz9eL2Ggg8" href='#jce-judge/open/Voz9eL2Ggg8' target='_self'><span>산점도 그리기 - sine 그래프</span></a>

# %% [markdown]
# **(3) 판다스 이용하기**
#
#
# > Pandas.Series 형태의 데이터를 다음과 같이 `scatter` 함수로 산점도로 나타낼 수 있습니다.
# >
# > `plt.scatter(Series1, Series2)`
# > : Series1 에 따른 Series2 데이터를 산점도로 그림
# >
# > 그래프를 출력하기 위해서는 반드시 다음 코드를 연이어 실행해야합니다.
# > `plt.show()`

# %% [markdown]
# > **scikit-learn** 라이브러리에서 제공하는 **boston** 데이터에는 boston 지역 집들의 가격을 포함한 여러 특징의 정보를 담고 있습니다.
# >
# > |특징|설명|특징|설명|
# > |---|---|---|---|
# > |**CRIM**|범죄율|**DIS**|직업센터 거리|
# |**ZN**|넓은 거주지역 비율|**RAD**|고속도로 거리|
# |**INDUS**|상업지역 비율|**TAX**|재산세율|
# |**CHAS**|찰스강 유역|**PTRATIO**|학생수/교사수|
# |**NOX**|NO 농도|**B**|흑인 비율|
# |**RM**|방 개수|**LSTAT**|차상위자 비율|
# |**AGE**|고택 비율|**PRICE**|주택 가격|
# >
# > 각 특징과 주택 가격의 관계를 산점도로 나타내어 봅시다.
# > * 범죄율 - 주택 가격
# > * 방 개수 - 주택 가격
# >
# > 산점도를 그려보고 각 특징과 주택 가격이 어떤 관계가 있는지 생각해봅시다.

# %%
# 예제 4: scikit-learn 라이브러리에서 제고하는 boston 데이터 가져오기

from sklearn import datasets  # scikit-learn 라이브러리의 datasets 모듈을 불러옵니다.

boston_housing_data = datasets.load_boston()  # boston 데이터의 원자료(raw data)를 불러옴
boston = pd.DataFrame(boston_housing_data.data)  # 데이터 값으로 DataFrame 생성
boston.columns = boston_housing_data.feature_names  # 특징 이름을 DataFrame의 column 이름으로 저장
boston['PRICE'] = boston_housing_data.target  # 집 가격을 PRICE 열로 추가

boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  PRICE
# 0       15.3  396.90   4.98   24.0
# ...

# %%
# 예제 5: 판다스 데이터로 산점도 그리기
 
plt.scatter(boston['CRIM'], boston['PRICE'])  # 빈 figure에 산점도를 그림
plt.xlabel("범죄율")  # figure의 x축 이름 작성
plt.ylabel("주택 가격")  # figure의 y축 이름 작성
plt.show()  # figure를 출력

# %%
# 예제 6: 판다스 데이터로 산점도 그리기
 
plt.scatter(boston['RM'], boston['PRICE'])  # 빈 figure에 산점도를 그림
plt.xlabel("방 개수")  # figure의 x축 이름 작성
plt.ylabel("주택 가격")  # figure의 y축 이름 작성
plt.show()  # figure를 출력

# %% [markdown]
# #### <연습문제>
#
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="csGicifjhfc" href='#jce-judge/open/csGicifjhfc' target='_self'><span>산점도 그리기 - 학생수/교사수에 따른 주택가격</span></a>
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="gw29YaaFpII" href='#jce-judge/open/gw29YaaFpII' target='_self'><span>산점도 그리기 - 일산화질소 농도에 따른 주택가격</span></a>

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>2. 산점도 겹쳐 그리기</h2>
# </div>

# %% [markdown]
# ###  **1. 산점도와 데이터**

# %% [markdown]
# **(1) 산점도로 겹쳐 그리기 좋은 데이터**
#
# > 다음은 2013년 미국 미식축구 리그(NFL) 선수들의 몸무게(weight)에 따른 키(height)를 산점도로 나타낸 그래프입니다.
# > 위는 수비수(Defense), 아래는 공격수(Offense) 데이터로 그려진 그래프입니다.
# > 각 그래프에는 선수의 포지션 별로 점의 색깔을 다르게 표시해두었습니다.
# >
# > 그래프를 통해 프로 미식축구 선수들의 몸무게-키 관계 특징이 포지션 별로 구분된다는 것을 알 수 있습니다.
# >
# > ![image.png](attachment:3c6f4b7e-b883-4869-b64b-9543116d3cd2.png)
# > 출처: https://www.reddit.com/r/nfl/comments/1oh84i/visualizing_the_height_and_weight_of_current_nfl/

# %% [markdown]
# > **두 변수간의 관계를 나타내고 비교할 데이터를 더 알아봅시다.**
# > * 펭귄의 종 별 키 - 몸무게
# > * 포도의 품종 별 당도 - 강도
# > * 지역 별 주택 크기 - 주택 가격
# >
# > **위에 소개한 예시 이외에 산점도로 겹쳐서 표현하면 좋을 데이터를 아랫칸에 적어봅시다.**

# %% [raw]
#       👉 (...) 별 (...) - (...)

# %% [markdown]
# ### **2. 산점도 겹쳐 그리기**
#
#
# > `scatter` 함수를 이용해 그래프를 겹쳐 그리는 방법은 크게 두가지로 나눌 수 있습니다.
# >
# > 첫번째, scatter 함수를 두 번 연달아 사용한다.
# > ①  `scatter.plot(data1)` 를 통해 빈 figure에 첫번째 데이터를 이용한 산점도를 그릴 수 있습니다.
# > ②  `scatter.plot(data2)` 를 통해 figure에 두번째 데이터를 이용한 산점도를 추가해서 그릴 수 있습니다.
# > ③  `plt.show()` 를 통해 figure를 출력할 수 있습니다.
# >
# > 두번째, `scatter` 함수에 두 데이터를 합쳐서 넣고 라벨 데이터로 점 색깔을 구분한다.
# > ①  `plt.scatter(data, c=data-label)` 를 통해 빈 figure에 점 색깔로 구분된 여러 산점도를 그릴 수 있습니다.
# > ②  `plt.show()` 를 통해 figure를 출력할 수 있습니다.

# %% [markdown]
# **(1) scatter 함수를 연달아 사용하는 방법**
#
# > Numpy.array 형태의 데이터를 이용하여 scatter 함수로 여러개의 산점도로 나타내는 방법을 설명하겠습니다.
# >
# > `plt.scatter(Array_X1, Array_Y1)` : 빈 figure에 Array_X1 에 따른 Array_Y1 데이터를 산점도로 그림
# > `plt.scatter(Array_X2, Array_Y2)` : 위의 figure에 Array_X2 에 따른 Array_Y2 데이터를 산점도로 겹쳐 그림
# >
# > 그래프를 출력하기 위해서는 반드시 다음 코드를 연이어 실행해야합니다.
# > `plt.show()`

# %%
# 예제 1: Numpy.array 데이터로 산점도 그리기

import numpy as np  # numpy 라이브러리를 사용하기 위해 np로 축약하여 불러옵니다.

X1 = np.arange(1, 5, 0.1)  # 0 부터 0.1 간격으로 1이상 5 미만까지의 수를 array에 저장
Y1 = 0.5* X1 + (np.random.rand(len(X1)) - 0.5)  # X1 안의 수 x에 대해서 0.5*x 값에 난수(-0.5 ~ 0.5)를 더해 array에 저장

X2 = np.arange(2, 6, 0.1)  # 0 부터 0.1 간격으로 2이상 6 미만까지의 수를 array에 저장
Y2 = 1* X2 + (np.random.rand(len(X2)) - 0.5)  # X2 안의 수 x에 대해서 x 값에 난수(-0.5 ~ 0.5)를 더해 array에 저장

plt.scatter(X1, Y1)  # 빈 figure에 산점도를 그림
plt.scatter(X2, Y2)  # 위의 figure에 산점도를 겹쳐서 그림
plt.xlabel('x')  # figure의 x축 이름 작성
plt.ylabel('y')  # figure의 y축 이름 작성
plt.show()  # figure를 출력

# %% [markdown]
# > 각각의 산점도가 어떤 데이터의 값인지 표현하고 싶다면 다음과 같이 그래프의 범례를 정할 수 있습니다.
# >
# > 첫번째, 각 그래프에 label 설정
# > `plt.scatter(Array_X1, Array_Y1, label='label1')` : 빈 figure에 label1 산점도를 그림
# > `plt.scatter(Array_X2, Array_Y2, label='label2')` : 위의 figure에 label2 산점도를 겹쳐서 그림
# > `plt.legend()`
# > : figure안에 각 그래프의 label을 적은 범례를 작성
# >
# > 두번째, legend 함수안에 label 리스트 설정
# > `plt.legend(['label1', 'label2'])`: 산점도가 그려진 순서대로 리스트의 label을 부여해 범례를 작성

# %%
# 예제 2: Numpy.array 데이터로 산점도 그리고 범례 추가

plt.scatter(X1, Y1)  # 빈 figure에 산점도를 그림
plt.scatter(X2, Y2)  # 위의 figure에 산점도를 겹쳐서 그림
plt.xlabel('x')  # figure의 x축 이름 작성
plt.ylabel('y')  # figure의 y축 이름 작성
plt.legend(['기울기 0.5', '기울기 1'])  # 범례 작성
plt.show()  # figure를 출력

# %% [markdown]
# > 산점도를 그릴때에는 점(marker)의 모양을 선택할 수 있습니다.
# > 여러개의 산점도를 그릴때 서로 다른 모양을 선택하면 점을 구분하는데 도움이 됩니다.
# >
# > `plt.scatter(data, marker='marker-style')` : 지정된 모양의 점으로 산점도를 그림
# >* `'o'` : 원
# >* `'^'` : 세모
# >* `'s'` : 네모
# >* `'*'` : 별

# %%
# 예제 3: Numpy.array 데이터로 산점도 다른 점 모양으로 그리기

plt.scatter(X1, Y1, marker='o')  # 빈 figure에 산점도를 원모양 점으로 그림
plt.scatter(X2, Y2, marker='s')  # 위의 figure에 산점도를 네모모양 점으로 겹쳐서 그림
plt.xlabel('x')  # figure의 x축 이름 작성
plt.ylabel('y')  # figure의 y축 이름 작성
plt.legend(['기울기 0.5', '기울기 1'])  # 범례 작성
plt.show()  # figure를 출력

# %% [markdown]
# #### <연습문제>
#
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="6qmUmpGjm7M" href='#jce-judge/open/6qmUmpGjm7M' target='_self'><span>산점도 중첩 - sine, cosine 그래프</span></a>
#
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="Z6zquYQKGBI" href='#jce-judge/open/Z6zquYQKGBI' target='_self'><span>산점도 중첩 - sine, cosine 그래프2</span></a>

# %% [markdown]
# **(2) 데이터 라벨 별로 점색깔 구분하는 방법**
#
# > Pandas.Series 형태의 데이터를 이용하여 scatter 함수로 여러개의 산점도를 나타내는 방법을 설명하겠습니다.
# >
# > `plt.scatter(Series1, Series2, c=Series-label)`
# > : Series1 에 따른 Series2 데이터를 Series-label 값에 따라 다른 색의 점으로 산점도를 그림
# > `plt.colorbar()`: 점 색깔 별 label 값을 작성
# >
# > 그래프를 출력하기 위해서는 반드시 다음 코드를 연이어 실행해야합니다.
# > `plt.show()`
# >
# > > 주의사항: Series-label의 값은 숫자 혹은 RGB color값(예: #bcbd22) 이어야 합니다.

# %% [markdown]
# > **seaborn** 라이브러리에서 제공하는 **iris** 데이터에는 붓꽃(iris)의 종류와 꽃받침, 꽃잎의 크기 정보를 담고 있습니다.
# >
# > |특징|설명|
# > |---|---|
# > |**sepal length**|꽃받침 길이|
# |**sepal width**|꽃받침 너비|
# |**petal length**|꽃잎 길이|
# |**petal width**|꽃잎 너비|
# |**species**|붓꽃의 종|
# >
# > 각 특징 간의 관계를 산점도로 나타내고 붓꽃의 종에 따라 구분하여 봅시다.
# > * 붓꽃의 종류 별 꽃받침 길이(sepal length) - 꽃잎 길이(petal length)
# > * 붓꽃의 종류 별 꽃받침 길이(sepal length) - 꽃받침 너비(sepal width)
# >
# > 산점도를 그려보고 붓꽃의 종류를 구분하기위해 필요한 특징이 무엇인지 생각해봅시다.

# %%
# 예제 4: seaborn 라이브러리에서 제공하는 iris 데이터 가져오기

import seaborn as sns  # seaborn 라이브러리를 sns로 축약하여 불러옵니다.

df = sns.load_dataset("iris")  # iris 데이터를 불러옵니다.
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# 예제 5: 판다스 데이터로 산점도 그리고 라벨에 따라 구분하기

color_label = df['species'].replace({'setosa': 0, 'versicolor': 1, 'virginica': 2})  # 붓꽃의 종에 따라 다른 숫자값을 가지는 label 시리즈 생성
 
plt.scatter(df['sepal_length'], df['petal_length'], c=color_label)  # 빈 figure에 산점도를 그리고 label에 따라 색깔로 구분
plt.xlabel("꽃받침 길이 (sepal length)")  # figure의 x축 이름 작성
plt.ylabel("꽃잎 길이 (petal length)")  # figure의 y축 이름 작성
plt.colorbar()  # 점 색깔 별 label 값을 작성
plt.show()  # figure를 출력

# %% [markdown]
# > 위의 그래프를 보면 세 종의 붓꽃이 그래프 안에서 잘 구분됩니다.
# > 따라서 꽆잎의 길이와 꽆받침의 길이를 알면 붓꽃의 종류를 추정할 수 있습니다.

# %%
# 예제 6: 판다스 데이터로 산점도 그리고 라벨에 따라 구분하기

color_label = df['species'].replace({'setosa': 0, 'versicolor': 1, 'virginica': 2})  # 붓꽃의 종에 따라 다른 숫자값을 가지는 label 시리즈 생성
 
plt.scatter(df['sepal_length'], df['sepal_width'], c=color_label)  # 빈 figure에 산점도를 그리고 label에 따라 색깔로 구분
plt.xlabel("꽃받침 길이 (sepal length)")  # figure의 x축 이름 작성
plt.ylabel("꽃받침 너비 (sepal width)")  # figure의 y축 이름 작성
plt.colorbar()  # 점 색깔 별 label 값을 작성
plt.show()  # figure를 출력

# %% [markdown]
# > 위의 그래프를 보면 versicolor, verginica 종류는 점들이 섞여 구분되지 않습니다.
# > 따라서 꽆받침의 길이와 너비만 안다면 붓꽃의 종류를 추정하기 어렵습니다.

# %% [markdown]
# #### <연습문제>
#
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="TngPU_CH4wE" href='#jce-judge/open/TngPU_CH4wE' target='_self'><span>산점도 중첩 - 펭귄 부리 길이와 깊이</span></a>
#
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="TMClUfDB13k" href='#jce-judge/open/TMClUfDB13k' target='_self'><span>산점도 중첩 - 펭귄 날개 길이와 몸무게</span></a>
